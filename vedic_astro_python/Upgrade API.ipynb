# %%
from AstroChart import AstroChart
# user data
city = 'Snezhinsk'
country = 'Russia'
birth_date = "20.01.1987"
birth_time = "10:53:00"
latitude, longitude = "56.085", "60.73"

# %%
# user data
#city = 'Odintsovo'
#country = 'Cyprus'
#birth_date = "24.12.1991"
#birth_time = "19:50:00"
#latitude, longitude = "55.67", "37.26"

# %%
ac = AstroChart(birth_date, birth_time, latitude, longitude)
rasi_chart = ac.build_rasi_chart()
# Out:
# C:\Users\Ivan\ai_astrology\vedic_astro_python\AstroChart.py:501: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Ретроградность"] = df["Ретроградность"].fillna(False)

# %%
rasi_chart
# Out:
#      Планета      Знак  Ретроградность    Градусы           Накшатра  \
# 0  Асцендент      Рыбы           False  +00:23:19   Пурва Бхадрапада
# 1     Солнце   Козерог           False  +05:57:07      Уттара Ашадха
# 2       Луна      Дева           False  +03:32:51    Уттара Пхалгуни
# 3   Меркурий   Козерог           False  +10:53:37            Шравана
# 4     Венера  Скорпион           False  +19:09:01           Джьештха
# 5       Марс      Рыбы           False  +14:31:23  Уттара Бхадрапада
# 6     Юпитер   Водолей           False  +27:14:06   Пурва Бхадрапада
# 7     Сатурн  Скорпион           False  +23:43:54           Джьештха
# 8       Раху      Рыбы            True  +21:48:01             Ревати
# 9       Кету      Дева            True  +21:48:01              Хаста
#
#   Управитель Управитель накшатры Абр  Дом Управляет домами     Аспекты  \
# 0     Юпитер              Юпитер  As    1               []          []
# ...

# %%
print(ac.utc_offset)
# Out:
# +05:00

# %%
sign_to_house = ac._build_sign_to_house_map(rasi_chart)

# %%
sign_to_house
# Out:
# {1: 12, 2: 1, 3: 2, 4: 3, 5: 4, 6: 5, 7: 6, 8: 7, 9: 8, 10: 9, 11: 10, 12: 11}

# %%
navamsa_chart = ac.build_navamsa_chart(rasi_chart)

# %%
#ac.navamsa_planet_to_house_map

# %%
navamsa_chart
# Out:
#      Планета      Знак    Градусы Абр Управитель  Дом Управляет домами  \
# 0  Асцендент       Рак  +03:29:51  As       Луна    1               []
# 1     Солнце   Водолей  +23:34:03  Su     Сатурн    8              [2]
# 2       Луна   Водолей  +01:55:39  Mo     Сатурн    8              [1]
# 3   Меркурий      Овен  +08:02:33  Me       Марс   10          [3, 12]
# 4     Венера   Стрелец  +22:21:09  Ve     Юпитер    6          [4, 11]
# 5       Марс  Скорпион  +10:42:27  Ma       Марс    5          [5, 10]
# 6     Юпитер  Близнецы  +05:06:54  Ju   Меркурий   12           [6, 9]
# 7     Сатурн   Водолей  +03:35:06  Sa     Сатурн    8           [7, 8]
# 8       Раху   Козерог  +16:12:09  Ra     Сатурн    7               []
# 9       Кету       Рак  +16:12:09  Ke       Луна    1               []
#
#        Аспекты     Отношение         Роль
# 0           []             -            -
# 1          [2]  Большой враг   Нейтрально
# 2          [2]          Враг  Благодетель
# ...

# %%
sign_to_house = ac._build_sign_to_house_map(navamsa_chart)

# %%
sign_to_house
# Out:
# {1: 4, 2: 5, 3: 6, 4: 7, 5: 8, 6: 9, 7: 10, 8: 11, 9: 12, 10: 1, 11: 2, 12: 3}

# %%
api_result = build_api_response({
    "rasi": rasi_chart,
    "navamsa": navamsa_chart
}, ayanamsa="Lahiri")

# %%
api_result
# Out:
# {'charts': {'rasi': {'type': 'RASI',
#    'planets': [{'planet': 'Асцендент',
#      'abbr': 'As',
#      'sign': 'Рыбы',
#      'degree': '+00:23:19',
#      'house': 1,
#      'aspects': [],
#      'role': '-',
#      'relation': '-',
#      'is_retrograde': False,
#      'nakshatra': 'Пурва Бхадрапада',
#      'sign_lord': 'Юпитер',
#      'nakshatra_lord': 'Юпитер',
#      'houses_ruled': []},
#     {'planet': 'Солнце',
#      'abbr': 'Su',
#      'sign': 'Козерог',
#      'degree': '+05:57:07',
#      'house': 11,
#      'aspects': [5],
#      'role': 'Вредитель',
#      'relation': 'Нейтрально',
#      'is_retrograde': False,
#      'nakshatra': 'Уттара Ашадха',
#      'sign_lord': 'Сатурн',
#      'nakshatra_lord': 'Солнце',
#      'houses_ruled': [6]},
#     {'planet': 'Луна',
#      'abbr': 'Mo',
#      'sign': 'Дева',
#      'degree': '+03:32:51',
#      'house': 7,
#      'aspects': [1],
#      'role': 'Благодетель',
#      'relation': 'Нейтрально',
# ...
